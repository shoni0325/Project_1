# %%
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %%
df2016 = pd.read_csv('../data/벤처기업정밀실태조사보고서/2016/벤처기업정밀실태조사 마이크로데이터_2016년.csv', encoding='cp949')
df2017 = pd.read_csv('../data/벤처기업정밀실태조사보고서/2017/벤처기업정밀실태조사 마이크로데이터_2017년.csv', encoding='cp949')
df2018 = pd.read_csv('../data/벤처기업정밀실태조사보고서/2018/벤처기업정밀실태조사 마이크로데이터_2018년.csv', encoding='cp949')

# %%
pd.set_option('display.max_seq_items', None)
df2016.columns
# Out:
# Index(['가중', '[쿼터] 지역', '[쿼터] 업종', '[쿼터] 규모', 'A1-4 벤처확인 유형',
#        'A1-5 회사주소 - 시(도)', 'A1-6-1 1단계 업종분류', 'A1-6-2 2단계 업종분류',
#        'A1-6-3 3단계 업종분류', 'A1-6-3 3단계 업종분류(내용)', 'A2-1 창업년도', 'A2-2 기업 성장단계',
#        'A2-3 제조 및 비제조', 'A2-4 상장여부 및 상장계획', 'A2-4 상장사 - 상장년도',
#        'A2-4 상장사 - 상장유형', 'A2-5 본사나 공장_ 연구소 위치 1 벤처촉진지구',
#        'A2-5 본사나 공장_ 연구소 위치 2 테크노파크', 'A2-5 본사나 공장_ 연구소 위치 3 창업보육센터',
#        'A2-5 본사나 공장_ 연구소 위치 4 벤처집적시설', 'A2-5 본사나 공장_ 연구소 위치 5 협동화단지',
#        'A2-5 본사나 공장_ 연구소 위치 6 신기술창업 집적지역', 'A2-5 본사나 공장_ 연구소 위치 7 아파트형 공장',
#        'A2-5 본사나 공장_ 연구소 위치 8 국가 및 지방산업단지', 'A2-5 본사나 공장_ 연구소 위치 9 기타 일반지역',
#        'B1-1 대표이사 성별', 'B1-2 대표이사 연령(세)', 'B1-3 대표이사 최종학력',
#        'B1-3-1 대표이사 전공(대졸전문학사)', 'B1-3-1 대표이사 전공(대졸전문학사)(기타내용)',
#        'B1-3-2 대표이사 전공(석사이상) 1 공학', 'B1-3-2 대표이사 전공(석사이상) 2 자연과학',
#        'B1-3-2 대표이사 전공(석사이상) 3 경영경제학', 'B1-3-2 대표이사 전공(석사이상) 4 인문사회학',
#        'B1-3-2 대표이사 전공(석사이상) 5 기타', 'B1-3-2 대표이사 전공(석사이상)(기타내용)',
# ...

# %%
# 모든 데이터프레임의 컬럼명 가져오기
columns = set(df2016.columns).union(df2017.columns).union(df2018.columns)

# 공통되지 않은 컬럼명 출력
different_columns = [col for col in columns if col not in df2016.columns or col not in df2017.columns or col not in df2018.columns]
print(different_columns)
# Out:
# ['D5 2017년 정부 정책지원 경험여부', 'D2-1 2014년 자산(백만원)', 'C6 2016년 퇴사 임직원 수 - 중간관리자급', 'D4 2015년 매출구조(퍼센트) - 해외', 'D1 2016년 지분구조(퍼센트) 7 타기업', 'G1-3 민간 연구기관 - 협력유형 1 마케팅-판로-유통', 'D1 2017년 지분구조(퍼센트) 5 일반 임직원', 'H2-2-7 은행-금융 기관소개 알선 - 도움정도', 'D1 2015년 지분구조(퍼센트) 7 타기업', 'D3-1 2016년 매출액(백만원)', 'C3-1 2017년 직종별 인력구성(명) - 합계', 'C1-3 2016년 총 종사자 수 - 합계', 'C1-1 2017년 총 정규직 수 - 남성', 'D1 2016년 지분구조(퍼센트) 5 일반 임직원', 'G2-3 민간 연구기관 - 협력희망분야 1 마케팅_판로_유통', 'D4 2017년 매출구조(퍼센트) - 국내(B2B) 대기업에 납품하는 12차 벤더', 'G2-6 해외 외국계기업 - 협력희망분야 1 마케팅-판로-유통', 'F3-1 2015년 국내 시장점유율(퍼센트)', 'D3-2 2015년 영업이익(백만원)', 'C1-2 2016년 총 비정규직 수 - 여성', 'C6 2016년 퇴사 임직원 수 - 사원급', 'C3-1 2016년 직종별 인력구성(명) - 기타', 'C6 2015년 퇴사 임직원 수 - 중간관리자급', 'J7 실천하고 있는 내용 3 윤리-투명 경영', 'D4 2016년 매출구조(퍼센트) - 해외', 'C5-1 신규채용 예상 인력(명) - 2018년', 'J6 현재 가장 필요하거나 중요한 교육 8 생산-품질관리 교육', 'C1-2 2016년 총 비정규직 수 - 남성', 'D7 2016년 투자처별 투자액(백만원) - 국내연구개발(RnD)', 'D3-2 2014년 영업이익(백만원)', 'J6 현재 가장 필요하거나 중요한 교육 8 생산_품질관리 교육', 'C2 2015년 외국인 수 - 여성', 'J7 실천하고 있는 내용 3 윤리_투명 경영', 'D1 2
# ...

# %%
len(different_columns)
# Out:
# 292

# %% [markdown]
# #### 특정 단어 포함 컬럼 삭제
#
# * '협력희망분야'
# * '협력유형'

# %%
# 컬럼 삭제
columns_to_drop = [col for col in df2018.columns if '협력희망분야' in col]
df2018.drop(columns=columns_to_drop, inplace=True)

# %%
# 컬럼 삭제
columns_to_drop = [col for col in df2018.columns if '협력유형' in col]
df2018.drop(columns=columns_to_drop, inplace=True)

# %%
len(df2018.columns)
# Out:
# 426

# %%
pd.set_option('display.max_seq_items', None)
df2018.columns
# Out:
# Index(['순번', '가중', '[쿼터] 지역', '[쿼터] 업종', '[쿼터] 규모', 'A1-4 벤처확인 유형',
#        'A1-5 회사주소 - 시(도)', 'A1-6-1 1단계 업종분류', 'A1-6-2 2단계 업종분류',
#        'A1-6-3 3단계 업종분류', 'A1-6-3 3단계 업종분류(내용)', 'A2-1 창업년도', 'A2-2 기업 성장단계',
#        'A2-3 제조 및 비제조', 'A2-4 상장여부 및 상장계획', 'A2-4 상장사 - 상장년도',
#        'A2-4 상장사 - 상장유형', 'A2-5 본사나 공장_ 연구소 위치 1 벤처촉진지구',
#        'A2-5 본사나 공장_ 연구소 위치 2 테크노파크', 'A2-5 본사나 공장_ 연구소 위치 3 창업보육센터',
#        'A2-5 본사나 공장_ 연구소 위치 4 벤처집적시설', 'A2-5 본사나 공장_ 연구소 위치 5 협동화단지',
#        'A2-5 본사나 공장_ 연구소 위치 6 신기술창업 집적지역', 'A2-5 본사나 공장_ 연구소 위치 7 아파트형 공장',
#        'A2-5 본사나 공장_ 연구소 위치 8 국가 및 지방산업단지', 'A2-5 본사나 공장_ 연구소 위치 9 기타 일반지역',
#        'B1-1 대표이사 성별', 'B1-2 대표이사 연령(세)', 'B1-3 대표이사 최종학력',
#        'B1-3-1 대표이사 전공(대졸전문학사)', 'B1-3-1 대표이사 전공(대졸전문학사)(기타내용)',
#        'B1-3-2 대표이사 전공(석사이상) 1 공학', 'B1-3-2 대표이사 전공(석사이상) 2 자연과학',
#        'B1-3-2 대표이사 전공(석사이상) 3 경영경제학', 'B1-3-2 대표이사 전공(석사이상) 4 인문사회학',
#        'B1-3-2 대표이사 전공(석사이상) 5 기타', 'B1-3-2 대표이사 전공(석사이상)(기타내용)',
# ...

# %% [markdown]
# #### 창업 당시 창업주 전공 데이터 변환

# %%
# 확인
pd.set_option('display.max_rows', None)
df2018[['B2-4-1 창업 당시 창업주 전공(대졸전문학사)', 'B2-4-1 창업 당시 창업주 전공(대졸전문학사)(기타내용)',
       'B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학', 'B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학',
       'B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학',
       'B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학', 'B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타']]

# %% [markdown]
# > 인문사회학부터 비교

# %%
# S = df2018[df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'] == 4.0]

# %%
# D = S[S['B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] != S['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학']]

# %%
# D[['B2-4-1 창업 당시 창업주 전공(대졸전문학사)', 'B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학']]
# Out:
#       B2-4-1 창업 당시 창업주 전공(대졸전문학사)  B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학
# 1561                          1.0                                4.0
# 2057                          1.0                                4.0

# %%
# print(df2018['B2-4-1 창업 당시 창업주 전공(대졸전문학사)'][2057])
# print(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'][2057])
# Out:
# 1.0
# 4.0

# %%
# df2018.at[1561, 'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = 4.0

# %%
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'] == 3.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학']

# %% [markdown]
# TEST

# %%
# df2018[['B2-4-1 창업 당시 창업주 전공(대졸전문학사)', 'B2-4-1 창업 당시 창업주 전공(대졸전문학사)(기타내용)',
#        'B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학', 'B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학',
#        'B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학',
#        'B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학', 'B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타']]

# %%
# df2018_1 = df2018.copy()

# %% [markdown]
# >경영경제학

# %%
# S = df2018_1[df2018_1['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'] == 3.0]
# D = S[S['B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] != S['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학']]
# D[['B2-4-1 창업 당시 창업주 전공(대졸전문학사)', 'B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학']]
# Out:
#       B2-4-1 창업 당시 창업주 전공(대졸전문학사)  B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학
# 13                            1.0                                3.0
# 48                            1.0                                3.0
# 297                           5.0                                3.0
# 360                           1.0                                3.0
# 419                           1.0                                3.0
# 430                           1.0                                3.0
# 660                           2.0                                3.0
# 719                           1.0                                3.0
# 798                           1.0                                3.0
# 846                           4.0                                3.0
# 869                           2.0                                3.0
# 1096                          2.0                                3.0
# 1223                          1.0                                3.0
# ...

# %%
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'] == 3.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학']

# %%
# S = df2018_1[df2018_1['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'] == 3.0]
# D = S[S['B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] != S['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학']]
# D[['B2-4-1 창업 당시 창업주 전공(대졸전문학사)', 'B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학']]
# Out:
#       B2-4-1 창업 당시 창업주 전공(대졸전문학사)  B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학
# 48                            1.0                                3.0
# 360                           1.0                                3.0
# 798                           1.0                                3.0
# 1096                          2.0                                3.0
# 1223                          1.0                                3.0
# 1336                          1.0                                3.0
# 1559                          1.0                                3.0
# 1820                          1.0                                3.0

# %% [markdown]
# > 자연과학

# %%
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'] == 2.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학']

# %% [markdown]
# > 공학

# %%
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'] == 1.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학']

# %% [markdown]
# > 기타도 실행

# %%
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'] == 5.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타']

# %%
df2018.drop('B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학', axis=1, inplace=True)
df2018.drop('B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학', axis=1, inplace=True)
df2018.drop('B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학', axis=1, inplace=True)
df2018.drop('B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학', axis=1, inplace=True)
df2018.drop('B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타', axis=1, inplace=True)

# %% [markdown]
# ---

# %%
# 기타
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'] == 5.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타']

# 인문사회학
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'] == 3.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학']

# 경영경제학
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'] == 3.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학']

# 자연과학
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'] == 2.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학']

# 공학
df2018.loc[(df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학'] == 1.0) 
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 2 자연과학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 3 경영경제학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 4 인문사회학'].isna())
            & (df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 5 기타'].isna()),
            'B2-4-1 창업 당시 창업주 전공(대졸전문학사)'] = df2018['B2-4-2 창업 당시 창업주 전공(석사이상) 1 공학']

# %% [markdown]
# ---

# %%
pd.set_option('display.max_seq_items', None)
df2018.columns
# Out:
# Index(['순번', '가중', '[쿼터] 지역', '[쿼터] 업종', '[쿼터] 규모', 'A1-4 벤처확인 유형',
#        'A1-5 회사주소 - 시(도)', 'A1-6-1 1단계 업종분류', 'A1-6-2 2단계 업종분류',
#        'A1-6-3 3단계 업종분류', 'A1-6-3 3단계 업종분류(내용)', 'A2-1 창업년도', 'A2-2 기업 성장단계',
#        'A2-3 제조 및 비제조', 'A2-4 상장여부 및 상장계획', 'A2-4 상장사 - 상장년도',
#        'A2-4 상장사 - 상장유형', 'A2-5 본사나 공장_ 연구소 위치 1 벤처촉진지구',
#        'A2-5 본사나 공장_ 연구소 위치 2 테크노파크', 'A2-5 본사나 공장_ 연구소 위치 3 창업보육센터',
#        'A2-5 본사나 공장_ 연구소 위치 4 벤처집적시설', 'A2-5 본사나 공장_ 연구소 위치 5 협동화단지',
#        'A2-5 본사나 공장_ 연구소 위치 6 신기술창업 집적지역', 'A2-5 본사나 공장_ 연구소 위치 7 아파트형 공장',
#        'A2-5 본사나 공장_ 연구소 위치 8 국가 및 지방산업단지', 'A2-5 본사나 공장_ 연구소 위치 9 기타 일반지역',
#        'B1-1 대표이사 성별', 'B1-2 대표이사 연령(세)', 'B1-3 대표이사 최종학력',
#        'B1-3-1 대표이사 전공(대졸전문학사)', 'B1-3-1 대표이사 전공(대졸전문학사)(기타내용)',
#        'B1-3-2 대표이사 전공(석사이상) 1 공학', 'B1-3-2 대표이사 전공(석사이상) 2 자연과학',
#        'B1-3-2 대표이사 전공(석사이상) 3 경영경제학', 'B1-3-2 대표이사 전공(석사이상) 4 인문사회학',
#        'B1-3-2 대표이사 전공(석사이상) 5 기타', 'B1-3-2 대표이사 전공(석사이상)(기타내용)',
# ...

# %%
df2018
# Out:
#         순번        가중  [쿼터] 지역  [쿼터] 업종  [쿼터] 규모  A1-4 벤처확인 유형
# 0        1  32.42529        5        5        2             4  \
# 1        2  32.05172        5        2        1             4
# 2        3  18.76563        5        2        2             2
# 3        4  26.43182        2        6        2             4
# 4        5   4.66000        1        8        4             2
# ...    ...       ...      ...      ...      ...           ...
# 2054  2055  32.05172        1        2        1             1
# 2055  2056  32.05172        4        2        1             1
# 2056  2057  36.94118        1        8        1             1
# 2057  2058  32.42529        1        5        2             1
# 2058  2059  18.76563        4        2        2             1
#
#      A1-5 회사주소 - 시(도)  A1-6-1 1단계 업종분류  A1-6-2 2단계 업종분류  A1-6-3 3단계 업종분류  ...
# 0                  전남               20              203            20321  ...  \
# ...
