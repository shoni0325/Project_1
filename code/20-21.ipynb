# %%
import pandas as pd

# %%
df_12 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2012년/벤처기업정밀실태조사 마이크로데이터_2012년.csv', encoding='euc-kr')
df_13 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2013년/벤처기업정밀실태조사 마이크로데이터_2013년.csv', encoding='euc-kr')
df_14 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2014년/벤처기업정밀실태조사 마이크로데이터_2014년.csv', encoding='cp949')
df_15 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2015년/벤처기업정밀실태조사 마이크로데이터_2015년.csv', encoding='cp949')
df_16 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2016년/벤처기업정밀실태조사 마이크로데이터_2016년.csv', encoding='cp949')
df_17 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2017년/벤처기업정밀실태조사 마이크로데이터_2017년.csv', encoding='cp949')
df_18 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2018년/벤처기업정밀실태조사 마이크로데이터_2018년.csv', encoding='cp949')
df_19 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2019년/벤처기업정밀실태조사 마이크로데이터_2019년.csv', encoding='cp949')
df_20 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2020년/벤처기업정밀실태조사 마이크로데이터_2020년.csv', encoding='cp949')
df_21 = pd.read_csv('/Users/taewon/Downloads/벤처기업/중소벤처기업부_벤처기업정밀실태조사보고서 (벤처기업협회)_20211231/2021년 벤처기업정밀실태조사(수정).csv', encoding='cp949')
# Out:
# /var/folders/28/yz261nq91vq_lj47hynw_10r0000gn/T/ipykernel_3391/285549057.py:4: DtypeWarning: Columns (128,129,130,131,132,133,134,135,136,167,169,170,171,485,487,489,491,492,495,498) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_15 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2015년/벤처기업정밀실태조사 마이크로데이터_2015년.csv', encoding='cp949')
# /var/folders/28/yz261nq91vq_lj47hynw_10r0000gn/T/ipykernel_3391/285549057.py:5: DtypeWarning: Columns (14,75,77,78,87,89,90,99,149,151,152,153,154,163,165,167,168,177,178,179) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_16 = pd.read_csv('/Users/taewon/Downloads/벤처기업/벤처기업정밀실태조사_2016년/벤처기업정밀실태조사 마이크로데이터_2016년.csv', encoding='cp949')
# /var/folders/28/yz261nq91vq_lj47hynw_10r0000gn/T/ipykernel_3391/285549057.py:6: DtypeWarning: Columns (153) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
df_20.drop(columns=['(쿼터) 지역', '(쿼터) 업종'], inplace=True)

# %%
df_21.drop(columns=['idx(번호)','업종(10대구분)', '업종(25대구분)'], inplace=True)

# %%
df_21.rename(columns={'ID(아이디)' : '아이디', '개인 _ 법인':'구분_법인_개인','A1_5_1 회사주소_시(도)':'A1-5_ 회사주소_시(도)','A1_5_2 회사주소_구(군)':'A1-5_ 회사주소_구(군)',
                      '규모 (쿼터) 규모':'(쿼터) 규모','A1_6_1 1단계 업종분류_대분류':'A1-6-1_ 1단계 업종분류_대분류','A1_6_2 2단계 업종분류_중분류':'A1-6-2_ 2단계 업종분류_중분류',
                      'A1_6  KSIC코드_10차':'A1-6_한국표준산업분류(KSIC)코드_10차','A1_4 벤처확인 유형':'A1-4_ 벤처확인 유형','A1_6_3 3단계 업종분류_소분류':'A1-6-3_ 3단계 업종분류_소분류',
                      'A2_1 창업년도(법인설립연도)':'A2-1_ 창업년도','A2_2 기업성장단계':'A2-2_ 기업성장단계','A2_3 제조 및 비제조':'A2-3_ 제조 및 비제조',
                      'A2_4 거래소나 코스닥 등 상장여부 및 향후 계획 여부':'A2-5_ 상장여부 및 향후계획','B1_1 현 대표이사는 귀사의 창업자입니까':'B1-1_ 현 대표이사와 창업자 동일여부',
                      'B2_1 창업자 성별':'B2-1_ 창업자 성별','B2_2 귀사 창업 당시 창업자의 연령':'B2-2_ 창업 당시 창업자 연령','B2_3_1a 창업자의 창업 당시 전공':'B2-3-1_ 창업 당시 창업자 전공',
                      'B2_3 창업자의 창업 당시 최종학력':'B2-3_ 창업 당시 창업자 최종학력','B2_4 창업자의 창업 직전근무지':'B2-4_ 창업 직전 근무지','B2_6_1 창업방식':'B2-6-1_ 창업방식',
                      'B2_6_2 단독창업여부':'B2-6-2_ 단독창업 여부','B2_6_3 창업자의 주요 역할은':'B2-6-3_ 창업자 역할','B2_7 창업 당시 귀사의 목표시장은':'B2-7_ 창업 당시 목표시장',
                      'B2_8 창업당시 창업자의 현 산업과 관련된 분야에서 실무경험 년수':'B2-8_ 창업 당시 창업자 실무경험 년수(년)','B2_9 B2-9  창업자 과거창업 경험 여부':'B2-9_ 창업자 과거창업 경험 여부',
                      'C1_1_1_1 2019년 정규직 수 (남성)':'C1-1_ 2019년 정규직_남성','C1_1_1_2 2019년 정규직 수 (여성)':'C1-1_ 2019년 정규직_여성',
                      'C1_1_1_3 2019년 정규직 수 (합계)':'C1-1_ 2019년 정규직_합계','C1_2_1_1 2019년 비정규직 수 (남성)':'C1-2_ 2019년 비정규직_남성',
                      'C1_2_1_2 2019년 비정규직 수 (여성)':'C1-2_ 2019년 비정규직_여성','C1_2_1_3 2019년 비정규직 수 (합계)':'C1-2_ 2019년 비정규직_합계',
                      'C1_3_1_1 2019년 총 종사자 수 (남성)':'C1-3_ 2019년 총 종사자_남성','C1_3_1_2 2019년 총 종사자 수 (여성)':'C1-3_ 2019년 총 종사자_여성',
                      'C1_3_1_3 2019년 총 종사자 수 (합계)':'C1-3_ 2019년 총 종사자_합계','C2_1_1 2020년 말 직종별 인력구성 - 관리':'C2-1_ 직종별 인력구성_관리',
                      'C2_1_2 2020년 말 직종별 인력구성 - 생산':'C2-1_ 직종별 인력구성_생산','C2_1_3 2020년 말 직종별 인력구성 - 영업':'C2-1_ 직종별 인력구성_영업',
                      'C2_1_4 2020년 말 직종별 인력구성 - R_D':'C2-1_ 직종별 인력구성_RnD','C2_1_5 2020년 말 직종별 인력구성 - 기타':'C2-1_ 직종별 인력구성_기타',
                      'C2_1_6 2020년 말 직종별 인력구성 - 합계':'C2-1_ 직종별 인력구성_합계','C2_2_1 2020년 말 직종별 부족인원 - 관리':'C2-1_ 직종별 부족인원_관리',
                      'C2_2_2 2020년 말 직종별 부족인원 - 생산':'C2-1_ 직종별 부족인원_생산','C2_2_3 2020년 말 직종별 부족인원 - 영업':'C2-1_ 직종별 부족인원_영업',
                      'C2_2_4 2020년 말 직종별 부족인원 - R_D':'C2-1_ 직종별 부족인원_연구개발(RnD)','C2_2_5 2020년 말 직종별 부족인원 - 기타':'C2-1_ 직종별 부족인원_기타',
                      'C2_2_6 2020년 말 직종별 부족인원 - 합계':'C2-1_ 직종별 부족인원_합계','C3_1_1 고용인력의 학력별 인력구성 - 박사':'C3_ 학력별 인력구성_박사',
                      'C3_1_2 고용인력의 학력별 인력구성 - 석사':'C3_ 학력별 인력구성_석사','C3_1_3 고용인력의 학력별 인력구성 - 대졸':'C3_ 학력별 인력구성_대졸',
                      'C3_1_4 고용인력의 학력별 인력구성 - 전문대졸':'C3_ 학력별 인력구성_전문대졸','C3_1_5 고용인력의 학력별 인력구성 - 고졸이하':'C3_ 학력별 인력구성_고졸이하',
                      'C3_1_6 고용인력의 학력별 인력구성 - 합계':'C3_ 학력별 인력구성_합계','C5_1_1 구인하기 어려운 직무(1순위)':'C5-1_ 현재 구인하기 어려운 직무(1순위)',
                      'C5_1_2 구인하기 어려운 직무(2순위)':'C5-1_ 현재 구인하기 어려운 직무(2순위)','C5_2_1 구인하기 어려운 직급(1순위)':'C5-2_ 현재 구인하기 어려운 직급(1순위)',
                      'C5_2_2 구인하기 어려운 직급(2순위)':'C5-2_ 현재 구인하기 어려운 직급(2순위)','D1_1_1 보유지분 비율 - 임직원 (창업자)':'D1_ 지분구조(퍼센트)_창업자',
                      'D1_1_2 보유지분 비율 - 임직원 (대표이사 포함)':'D1_ 지분구조(퍼센트)_임직원','D1_1_3 보유지분 비율 - 가족 (대표이사나 임직원의 가족이나 친지포함)':'D1_ 지분구조(퍼센트)_가족',
                      'D1_1_4 보유지분 비율 - 벤처캐피털 및 기관투자자':'D1_ 지분구조(퍼센트)_벤처캐피털 및 기관투자자','D1_1_5 보유지분 비율 - 엔젤 및 액셀러레이터':'D1_ 지분구조(퍼센트)_엔젤 및 액셀러레이터',
                      'D1_1_6 보유지분 비율 - 개인투자자':'D1_ 지분구조(퍼센트)_개인투자자','D2_1_1 2019년 자산(백만원)':'D2-1_ 2019년 자산(백만원)','D2_2_1 2019년 부채(백만원)':'D2-2_ 2019년 부채(백만원)',
                      'D2_3_1 2019년 자본(백만원)':'D2-3_ 2019년 자본(백만원)','D3_4_1 2019년 당기순이익(백만원)':'D3-4_ 2019년 당기순이익(백만원)','D3_3_1 2019년 금융비용(백만원)':'D3-3_ 2019년 금융비용(백만원)',
                      'D3_2_1 2019년 영업이익(백만원)':'D3-2_ 2019년 영업이익(백만원)','D3_1_1 2019년 매출액(백만원)':'D3-1_ 2019년 매출액(백만원)','D4_ 매출구조(퍼센트)_(B2B)(대기업에 납품하는 1_2차 벤더)':'D4_ 2019년 매출구조(퍼센트)_(B2B)(대기업에 납품하는 1_2차 벤더)',
                      'D4_ 매출구조(퍼센트)_(B2B)(중견기업)':'D4_ 2019년 매출구조(퍼센트)_(B2B)(중견기업)','D4_ 매출구조(퍼센트)_(B2B)(중소기업 및 벤처기업)':'D4_ 2019년 매출구조(퍼센트)_(B2B)(중소기업 및 벤처기업)',
                      'D4_ 매출구조(퍼센트)_(B2B)대기업 또는 대기업그룹사 소속사':'D4_ 2019년 매출구조(퍼센트)_(B2B)대기업 또는 대기업그룹사 소속사','D4_ 매출구조(퍼센트)_(B2C)소비자 매출':'D4_ 2019년 매출구조(퍼센트)_(B2C)소비자 매출',
                      'D4_ 매출구조(퍼센트)_(B2G)정부 포함 공공부문 매출':'D4_ 2019년 매출구조(퍼센트)_(B2G)정부 포함 공공부문 매출','D4_ 매출구조(퍼센트)_해외':'D4_ 2019년 매출구조(퍼센트)_해외',
                      'D5_1_1 경험 여부 - R_D자금(출연금)':'D5-1_ 연구개발(RnD)자금(출연금)_경험여부','D5_2_1 경험 여부 - 융자(정책자금)':'D5-2_ 융자(정책자금)_경험여부',
                      'D5_3_1 경험 여부 - 보증서 지원(보증서발급 대출)':'D5-3_ 보증서지원_경험여부','D5_4_1 경험 여부 - 기타 지원(창업사업화 및 수출지원 등)':'D5-4_ 기타지원_경험여부',
                      'D7_ 투자처별 투자액(백만원)_국내설비':'D7_ 2019년 투자처별 투자액(백만원)_국내설비','D7_ 투자처별 투자액(백만원)_국내연구개발(RnD)':'D7_ 2019년 투자처별 투자액(백만원)_국내연구개발(RnD)',
                      'D7_ 투자처별 투자액(백만원)_기타':'D7_ 2019년 투자처별 투자액(백만원)_기타','D7_ 투자처별 투자액(백만원)_합계':'D7_ 2019년 투자처별 투자액(백만원)_합계',
                      'D7_ 투자처별 투자액(백만원)_해외':'D7_ 2019년 투자처별 투자액(백만원)_해외','F1_1 경쟁사 대비 현황_개발역량':'F1-1_ 경쟁사 대비 현황_개발역량',
                      'F1_2 경쟁사 대비 현황_제조역량':'F1-2_ 경쟁사 대비 현황_제조역량','F1_3 경쟁사 대비 현황_마케팅역량':'F1-3_ 경쟁사 대비 현황_마케팅역량','F2_1 경쟁전략초점_원가우위 수준':'F2-1_ 경쟁전략초점_원가우위 수준',
                      'F2_2 경쟁전략초점_제품 고부가가치화 수준':'F2-2_ 경쟁전략초점_제품 고부가가치화 수준','F3_1 비즈니스 모델_명확한 정리정도':'F3-1_ 비즈니스 모델_명확한 정리정도',
                      'F3_2 비즈니스 모델_혁신정도':'F3-2_ 비즈니스 모델_혁신정도','F4_ 장기적 성장 전망성':'F4 장기적 성장 전망성','G1_ 자체 브랜드_보유여부':'G1 자체 브랜드_보유여부',
                      'G2_ 영업 및 마케팅 방식':'G2 영업 및 마케팅 방식','G3_1 주력제품 국내 시장점유율':'G3-1_ 주력제품 국내 시장점유율(퍼센트)','G3_2 주력제품 해외 시장점유율':'G3-2_ 주력제품 해외 시장점유율(퍼센트)',
                      'G4_ 원자재나 부품 수입여부':'G4 원자재나 부품 수입 여부','G5_ 해외 사업 방식':'G5 2020년 기준 귀사의 해외 사업 방식은 어디에 해당되십니까',
                      'G7_1  해외수출 및 진출과정 애로사항(1순위)':'G7_ 해외수출 및 진출과정 애로사항(1순위)','G7_2  해외수출 및 진출과정 애로사항(2순위)':'G7_ 해외수출 및 진출과정 애로사항(2순위)',
                      'I1 크라우드 펀딩 경험여부':'I1_ 크라우드 펀딩 경험여부','I2  엔젤투자자 혹은 액셀러레이터 투자 경험여부':'I2_ 엔젤투자자 혹은 액셀러레이터 투자 경험여부',
                      'I3 벤처캐피털(투자조합포함) 투자 경험여부':'I3_ 벤처캐피털(투자조합포함) 투자 경험여부','I4 인수합병(M_A) 경험여부':'I4_ 인수합병(MnA) 경험여부',
                      'I5 피인수합병 경험여부':'I5_ 피인수합병 경험여부', 'I6 다른 업체를 인수합병 할 의향여부':'I6_ 다른 업체를 인수합병 할 의향여부','I7 다른 업체의 인수합병에 응할 의향여부':'I7_ 다른 업체의 인수합병에 응할 의향여부',
                      'I8_1 인수합병 환경개선을 위한 필요사항(1순위)':'I8_ 인수합병 환경개선을 위한 필요사항(1순위)','I8_2 인수합병 환경개선을 위한 필요사항(2순위)':'I8_ 인수합병 환경개선을 위한 필요사항(2순위)',
                      'J4_1 기업간 거래 시 애로사항(1순위)':'J4_ 기업간 거래시 애로사항(1순위)','K1_1 벤처확인제도를 통해 받는 혜택_ (기술개발 촉진효과)':'K1-1_ 벤처확인제도 혜택_기술개발 촉진효과',
                      'K1_2 벤처확인제도를 통해 받는 혜택_ (기업 이미지 제고 등 광고효과)':'K1-2_ 벤처확인제도 혜택_기업 이미지 제고 등 광고효과','K1_3 벤처확인제도를 통해 받는 혜택_ (세제 혜택 효과)':'K1-3_ 벤처확인제도 혜택_세제혜택 효과',
                      'K1_4 벤처확인제도를 통해 받는 혜택_ (우수 인력 확보에 유리)':'K1-4_ 벤처확인제도 혜택_우수인력 확보에 유리','K1_5 벤처확인제도를 통해 받는 혜택_ (입지 선정 시 유리)':'K1-5_ 벤처확인제도 혜택_입지 선정 시 유리',
                      'K1_6 벤처확인제도를 통해 받는 혜택_ (자금조달 및 투자 유인효과)':'K1-6_ 벤처확인제도 혜택_자금조달 및 투자 유인효과','K1_7 벤처확인제도를 통해 받는 혜택_ (정부지원제도 참여에 유리)':'K1-7_ 벤처확인제도 혜택_정부지원제도 참여에 유리',
                      'K1_8 벤처확인제도를 통해 받는 혜택_ (창업 관련 규제 완화 효과)':'K1-8_ 벤처확인제도 혜택_창업 관련 규제 완화 효과','K2_1 벤처 인프라 수준_ (M_A 활성화를 위한 제도개선)':'K2-1_ 현재 벤처인프라 수준_인수합병(MnA) 활성화를 위한 제도개선',
                      'K2_2 벤처 인프라 수준_ (벤처관련 규제완화)':'K2-2_ 현재 벤처인프라 수준_벤처관련 규제완화','K2_3 벤처 인프라 수준_ (창업 및 기업가적 능력개발을 위한 교육)':'K2-3_ 현재 벤처인프라 수준_창업 및 기업가적 능력개발을 위한 교육',
                      'K2_4 벤처 인프라 수준_ (기업가정신을 고취하는 사회분위기)':'K2-4_ 현재 벤처인프라 수준_기업가정신을 고취하는 사회분위기','K2_5 벤처 인프라 수준_ (벤처투자 활성화)':'K2-5_ 현재 벤처인프라 수준_벤처투자 활성화',
                      'K4_10 경영상 애로사항_ (조직관리 애로)':'K4-10_ 경영상 애로사항_조직관리','K4_11 경영상 애로사항_ (환율 변동 애로)':'K4-11_ 경영상 애로사항_환율변동',
                      'K4_12 경영상 애로사항_ (특허 분쟁 애로)':'K4-12_ 경영상 애로사항_특허분쟁','K4_13 경영상 애로사항_ (각종 규제 애로)':'K4-13_ 경영상 애로사항_각종규제',
                      'K4_14 경영상 애로사항_ (산학연 간 협력 활동 애로)':'K4-14_ 경영상 애로사항_산-학-연 간 협력활동','K4_15 경영상 애로사항_ (불공정한 시장질서 애로)':'K4-15_ 경영상 애로사항_불공정한 시장질서',
                      'K4_1 경영상 애로사항_ (신기술 개발 애로)':'K4-1_ 경영상 애로사항_신기술 개발','K4_2 경영상 애로사항_ (개발된 기술의 사업화 애로)':'K4-2_ 경영상 애로사항_개발된 기술의 사업화',
                      'K4_3 경영상 애로사항_ (국내 판로개척 애로)':'K4-3_ 경영상 애로사항_국내 판로개척','K4_4 경영상 애로사항_ (해외시장 개척 애로)':'K4-4_ 경영상 애로사항_해외시장 개척',
                      'K4_5 경영상 애로사항_ (필요인력의 확보 및 유지관리 애로)':'K4-5_ 경영상 애로사항_필요인력의 확보 및 유지관리','K4_6 경영상 애로사항_ (자금조달운용 등 자금관리 애로)':'K4-6_ 경영상 애로사항_자금조달_운용 등 자금관리',
                      'K4_7 경영상 애로사항_ (기술유출 및 디자인상표 도용 애로)':'K4-7_ 경영상 애로사항_기술유출 및 디자인_상표 도용','K4_8 경영상 애로사항_ (업계내의 과당경쟁 및 덤핑 애로)':'K4-8_ 경영상 애로사항_업계내의 과당경쟁 및 덤핑',
                      'K4_9 경영상 애로사항_ (법률회계세무 관련 지식 부족 애로)':'K4-9_ 경영상 애로사항_법률_회계_세무 관련 지식부족'
                      }, inplace=True)

# %%
df_20.dropna(axis=1, thresh=2000, inplace=True)

# %%
df_21.dropna(axis=1, thresh=2000, inplace=True)

# %%
data = pd.concat([df_20, df_21], ignore_index=True)

# %%
# 같은 값의 개수가 2 이상인 ID들을 필터링하여 새로운 데이터프레임 생성
# data2 = data[data['아이디'].duplicated(keep=False)]

# %%
# data2.sort_values(by='아이디',inplace=True)

# %%
# data2.reset_index(drop=True, inplace=True)

# %%
# data2.to_csv('중복데이터.csv', index=False, encoding='utf-8')

# %%
# data3 = data[data['A1-5_ 회사주소_구(군)'].duplicated(keep=False)]

# %%
data4 = data.sort_values(by='A1-6_한국표준산업분류(KSIC)코드_10차')

# %%
# 결측치 개수를 확인하여 2000개 이상인 컬럼 삭제
data5 = data4.dropna(axis=1, thresh=2000)

# %%
# 두 데이터프레임에서 컬럼 이름이 다른 컬럼만 출력
different_columns = set(df_20.columns) ^ set(df_21.columns)

# %%
different_columns
# Out:
# {'(쿼터) 규모',
#  'A1-4_ 벤처확인 유형',
#  'A1-5_ 회사주소_구(군)',
#  'A1-5_ 회사주소_시(도)',
#  'A1-6-1_ 1단계 업종분류_대분류',
#  'A1-6-2_ 2단계 업종분류_중분류',
#  'A1-6-3_ 3단계 업종분류_소분류',
#  'A1-6_한국표준산업분류(KSIC)코드_10차',
#  'A1_4 벤처확인 유형',
#  'A1_5_1 회사주소_시(도)',
#  'A1_5_2 회사주소_구(군)',
#  'A1_6  KSIC코드_10차',
#  'A1_6_1 1단계 업종분류_대분류',
#  'A1_6_2 2단계 업종분류_중분류',
#  'A1_6_3 3단계 업종분류_소분류',
#  'A2-1_ 창업년도',
#  'A2-2_ 기업성장단계',
#  'A2-3_ 일부 외주인 경우_ 아웃소싱 비중(퍼센트)',
#  'A2-3_ 제조 및 비제조',
#  'A2-4_ 스마트공장 도입의향',
#  'A2-5_ 상장여부 및 향후계획',
#  'A2-5_ 현재 상장기업_상장년도',
#  'A2-5_ 현재 상장기업_상장시장',
#  'A2_1 창업년도(법인설립연도)',
#  'A2_2 기업성장단계',
#  'A2_3 제조 및 비제조',
#  'A2_3_2_etc 아웃소싱 비중',
#  'A2_4 거래소나 코스닥 등 상장여부 및 향후 계획 여부',
#  'A2_4a 상장년도',
#  'A2_4b 상장시장',
#  'B1-1_ 현 대표이사와 창업자 동일여부',
#  'B1-2_ 대표이사 성별',
#  'B1-3_ 대표이사 연령(현재)',
#  'B1-4-1_ 대표이사 전공',
#  'B1-4_ 대표이사 최종학력(현재)',
#  'B1-5_ 대표이사 직전 근무지',
#  'B1-6_ 대표이사 이전 업무경력분야(1)',
#  'B1-6_ 대표이사 이전 업무경력분야(2)',
#  'B1-6_ 대표이사 이전 업무경력분야(3)',
#  'B1-6_ 대표이사 이전 업무경력분야(4)',
# ...

# %%
data5.isna().sum()
# Out:
# 아이디                                        0
# 구분_법인_개인                                   0
# 가중치                                        0
# (쿼터) 규모                                    0
# A1-4_ 벤처확인 유형                              0
#                                         ...
# F4 장기적 성장 전망성                           2770
# G1 자체 브랜드_보유여부                          2500
# G2 영업 및 마케팅 방식                          2500
# G4 원자재나 부품 수입 여부                        2770
# G5 2020년 기준 귀사의 해외 사업 방식은 어디에 해당되십니까    2770
# Length: 221, dtype: int64

# %%
# 결측치 개수를 확인하여 1000개 이상인 컬럼 삭제
data6 = data5.dropna(axis=1, thresh=data5.shape[0]-1000)

# %%
data6.reset_index(drop=True, inplace=True)

# %%
data6['C2-1_ 직종별 부족인원_영업'].isin([0]).sum()
# Out:
# 4585

# %%
data6.drop(columns=['C1-2_ 2019년 비정규직_남성','C1-2_ 2019년 비정규직_여성','C1-2_ 2019년 비정규직_합계'])
# Out:
#         아이디 구분_법인_개인     가중치  (쿼터) 규모  A1-4_ 벤처확인 유형 A1-5_ 회사주소_시(도)
# 0      9911       법인  10.420        1              3              경기  \
# 1       465       법인   3.484        4              1              광주
# 2     14557       법인  13.645        3              2              경남
# 3      7456       개인   1.700        1              2              광주
# 4       578       법인   1.832        6              2              서울
# ...     ...      ...     ...      ...            ...             ...
# 4995   3102       법인   1.350        8              3              서울
# 4996  13217       법인  30.356        2              1              서울
# 4997  35589       법인   0.323        7              2              경기
# 4998   1749       법인   0.323        7              2              서울
# 4999   1847       법인   1.350        8              2              서울
#
#      A1-5_ 회사주소_구(군)  A1-6_한국표준산업분류(KSIC)코드_10차 A1-6-1_ 1단계 업종분류_대분류
# ...

# %%
data6.to_csv('표준화data.csv', index=False, encoding='utf-8')

# %%
data6.columns[data6.isna().any()]
# Out:
# Index(['A2-5_ 상장여부 및 향후계획', 'B1-1_ 현 대표이사와 창업자 동일여부', 'B2-3-1_ 창업 당시 창업자 전공',
#        'B2-6-2_ 단독창업 여부', 'B2-7_ 창업 당시 목표시장', 'D1_ 지분구조(퍼센트)_창업자',
#        'D1_ 지분구조(퍼센트)_임직원', 'D1_ 지분구조(퍼센트)_가족', 'D1_ 지분구조(퍼센트)_벤처캐피털 및 기관투자자',
#        'D1_ 지분구조(퍼센트)_엔젤 및 액셀러레이터', 'D1_ 지분구조(퍼센트)_개인투자자',
#        'F1-1_ 경쟁사 대비 현황_개발역량', 'F1-2_ 경쟁사 대비 현황_제조역량', 'F1-3_ 경쟁사 대비 현황_마케팅역량',
#        'F2-1_ 경쟁전략초점_원가우위 수준', 'F2-2_ 경쟁전략초점_제품 고부가가치화 수준',
#        'F3-1_ 비즈니스 모델_명확한 정리정도', 'F3-2_ 비즈니스 모델_혁신정도',
#        'G3-1_ 주력제품 국내 시장점유율(퍼센트)', 'G3-2_ 주력제품 해외 시장점유율(퍼센트)',
#        'G7_ 해외수출 및 진출과정 애로사항(1순위)', 'G7_ 해외수출 및 진출과정 애로사항(2순위)',
#        'I1_ 크라우드 펀딩 경험여부', 'I2_ 엔젤투자자 혹은 액셀러레이터 투자 경험여부',
#        'I3_ 벤처캐피털(투자조합포함) 투자 경험여부', 'I4_ 인수합병(MnA) 경험여부', 'I5_ 피인수합병 경험여부',
#        'I6_ 다른 업체를 인수합병 할 의향여부', 'I7_ 다른 업체의 인수합병에 응할 의향여부',
#        'I8_ 인수합병 환경개선을 위한 필요사항(1순위)', 'I8_ 인수합병 환경개선을 위한 필요사항(2순위)',
#        'J4_ 기업간 거래시 애로사항(1순위)'],
#       dtype='object')

# %%
# 0값이 포함된 컬럼 확인
zero_columns = data6.columns[data6.isin([0]).any()]
zero_columns
# Out:
# Index(['B2-8_ 창업 당시 창업자 실무경험 년수(년)', 'C1-1_ 2019년 정규직_남성',
#        'C1-1_ 2019년 정규직_여성', 'C1-1_ 2019년 정규직_합계', 'C1-2_ 2019년 비정규직_남성',
#        'C1-2_ 2019년 비정규직_여성', 'C1-2_ 2019년 비정규직_합계', 'C1-3_ 2019년 총 종사자_남성',
#        'C1-3_ 2019년 총 종사자_여성', 'C1-3_ 2019년 총 종사자_합계', 'C2-1_ 직종별 인력구성_관리',
#        'C2-1_ 직종별 인력구성_생산', 'C2-1_ 직종별 인력구성_영업', 'C2-1_ 직종별 인력구성_RnD',
#        'C2-1_ 직종별 인력구성_기타', 'C2-1_ 직종별 부족인원_관리', 'C2-1_ 직종별 부족인원_생산',
#        'C2-1_ 직종별 부족인원_영업', 'C2-1_ 직종별 부족인원_연구개발(RnD)', 'C2-1_ 직종별 부족인원_기타',
#        'C2-1_ 직종별 부족인원_합계', 'C3_ 학력별 인력구성_박사', 'C3_ 학력별 인력구성_석사',
#        'C3_ 학력별 인력구성_대졸', 'C3_ 학력별 인력구성_전문대졸', 'C3_ 학력별 인력구성_고졸이하',
#        'D1_ 지분구조(퍼센트)_창업자', 'D1_ 지분구조(퍼센트)_임직원', 'D1_ 지분구조(퍼센트)_가족',
#        'D1_ 지분구조(퍼센트)_벤처캐피털 및 기관투자자', 'D1_ 지분구조(퍼센트)_엔젤 및 액셀러레이터',
#        'D1_ 지분구조(퍼센트)_개인투자자', 'D2-1_ 2019년 자산(백만원)', 'D2-2_ 2019년 부채(백만원)',
#        'D2-3_ 2019년 자본(백만원)', 'D3-1_ 2019년 매출액(백만원)', 'D3-2_ 2019년 영업이익(백만원)',
# ...

# %%
data6.isin([0]).sum()
# Out:
# 아이디                             0
# 구분_법인_개인                        0
# 가중치                             0
# (쿼터) 규모                         0
# A1-4_ 벤처확인 유형                   0
#                                ..
# K4-11_ 경영상 애로사항_환율변동            0
# K4-12_ 경영상 애로사항_특허분쟁            0
# K4-13_ 경영상 애로사항_각종규제            0
# K4-14_ 경영상 애로사항_산-학-연 간 협력활동    0
# K4-15_ 경영상 애로사항_불공정한 시장질서       0
# Length: 124, dtype: int64
