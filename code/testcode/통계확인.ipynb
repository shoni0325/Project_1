# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/완성data/new_select_data.csv')

# %%
df.drop(columns=['벤처확인 유형'], inplace=True)

# %% [markdown]
# feature selection 후 data
# - Min&Max Scaling X
# - One Hot Encoding X

# %% [markdown]
# 1. 범주형 변수

# %%
# 엔젤투자자 혹은 액셀러레이터 투자 경험여부
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
a["엔젤투자자 혹은 액셀러레이터 투자 경험여부"].value_counts()
# Out:
# 0    722
# 1    195
# Name: 엔젤투자자 혹은 액셀러레이터 투자 경험여부, dtype: int64

# %%
print(772/917)
print(195/917)
# Out:
# 0.8418756815703381
# 0.21264994547437296

# %%
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
a["엔젤투자자 혹은 액셀러레이터 투자 경험여부"].value_counts()
# Out:
# 0    11228
# 1      239
# Name: 엔젤투자자 혹은 액셀러레이터 투자 경험여부, dtype: int64

# %%
print(11228/114467)
print(239/11467)
# Out:
# 0.09808940568023972
# 0.020842417371588037

# %%
y = df[df['엔젤투자자 혹은 액셀러레이터 투자 경험여부']==1]
z = df[df['엔젤투자자 혹은 액셀러레이터 투자 경험여부']==0]

y['벤처캐피털(투자조합포함) 투자 경험여부'].value_counts()
# Out:
# 0    239
# 1    195
# Name: 벤처캐피털(투자조합포함) 투자 경험여부, dtype: int64

# %%
195/434
# Out:
# 0.44930875576036866

# %%
z['벤처캐피털(투자조합포함) 투자 경험여부'].value_counts()
# Out:
# 0    11228
# 1      722
# Name: 벤처캐피털(투자조합포함) 투자 경험여부, dtype: int64

# %%
722/11950
# Out:
# 0.060418410041841

# %%
# 창업 당시 창업자 최종학력
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
a["창업 당시 창업자 최종학력"].value_counts()
# Out:
# 3    466
# 1    210
# 2    180
# 5     43
# 4     18
# Name: 창업 당시 창업자 최종학력, dtype: int64

# %%
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
a["창업 당시 창업자 최종학력"].value_counts()
# Out:
# 3    6408
# 2    1944
# 5    1405
# 1     959
# 4     751
# Name: 창업 당시 창업자 최종학력, dtype: int64

# %%
# 창업 직전 근무지
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
a["창업 직전 근무지"].value_counts()
# Out:
# 6     375
# 5     283
# 7      57
# 1      49
# 4      44
# 3      41
# 10     35
# 2      13
# 9      12
# 8       8
# Name: 창업 직전 근무지, dtype: int64

# %%
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
a["창업 직전 근무지"].value_counts()
# Out:
# 6     7114
# 5     2333
# 7      657
# 10     332
# 3      221
# 4      203
# 9      201
# 1      187
# 8      161
# 2       58
# Name: 창업 직전 근무지, dtype: int64

# %%
# 창업 당시 목표시장
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
a["창업 당시 목표시장"].value_counts()
# Out:
# 3.0    571
# 1.0    318
# 2.0     28
# Name: 창업 당시 목표시장, dtype: int64

# %%
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
a["창업 당시 목표시장"].value_counts()
# Out:
# 1.0    5700
# 3.0    5662
# 2.0     105
# Name: 창업 당시 목표시장, dtype: int64

# %%
# 해외수출 및 진출과정 애로사항
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
a["해외수출 및 진출과정 애로사항"].value_counts()
# Out:
# 3.0    201
# 2.0    174
# 4.0    174
# 7.0    125
# 5.0     98
# 1.0     63
# 8.0     45
# 6.0     37
# Name: 해외수출 및 진출과정 애로사항, dtype: int64

# %%
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
a["해외수출 및 진출과정 애로사항"].value_counts()
# Out:
# 3.0    2994
# 2.0    2332
# 4.0    1894
# 1.0    1442
# 5.0    1108
# 7.0     847
# 8.0     538
# 6.0     312
# Name: 해외수출 및 진출과정 애로사항, dtype: int64

# %%
# 연구개발관련전담부서보유여부
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
a["연구개발관련전담부서보유여부"].value_counts()
# Out:
# 1.0    755
# 2.0     65
# 3.0     63
# 4.0     34
# Name: 연구개발관련전담부서보유여부, dtype: int64

# %%
a = df[df["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
a["연구개발관련전담부서보유여부"].value_counts()
# Out:
# 1.0    8765
# 2.0    1077
# 3.0     851
# 4.0     774
# Name: 연구개발관련전담부서보유여부, dtype: int64

# %% [markdown]
# 2. 비율 & 수치형 변수

# %%
a = df[['부서별_인력구성(생산)',
 '부서별_인력구성(RnD)',
 '총자산회전율',
 '순이익률',
 'ROE',
 '주력제품 국내 시장점유율(퍼센트)',
 '학력별 인력구성비(대졸)',
 '벤처캐피털(투자조합포함) 투자 경험여부']]

# %%
a[a["벤처캐피털(투자조합포함) 투자 경험여부"]==1].describe()
# Out:
#        부서별_인력구성(생산)  부서별_인력구성(RnD)       총자산회전율         순이익률          ROE  \
# count    917.000000     917.000000   917.000000   917.000000   917.000000
# mean      27.111468      25.421239    95.389914   -73.110736   -19.147629
# std       24.427932      21.964548   110.016536   281.216658   201.694165
# min        0.000000       0.000000     0.000000 -1739.260000 -1787.500000
# 25%        1.316000       8.955000    45.268000   -20.984000   -21.993000
# 50%       22.222000      18.657000    74.709000     1.106000     3.833000
# 75%       48.718000      38.095000   119.463000     6.530000    14.538000
# max       96.296000     100.000000  1868.724000   175.477000  1112.500000
#
#        주력제품 국내 시장점유율(퍼센트)  학력별 인력구성비(대졸)  벤처캐피털(투자조합포함) 투자 경험여부
# count          917.000000     917.000000                  917.0
# mean            15.450218      54.359091                    1.0
# std             19.197304      23.405698                    0.0
# ...

# %%
a[a["벤처캐피털(투자조합포함) 투자 경험여부"]==0].describe()
# Out:
#        부서별_인력구성(생산)  부서별_인력구성(RnD)        총자산회전율          순이익률           ROE  \
# count  11467.000000   11467.000000  11467.000000  11467.000000  11467.000000
# mean      35.179606      21.352163    132.491756     -8.388219      7.546469
# std       26.268099      19.531841    130.686026    114.385938    124.269691
# min        0.000000       0.000000      0.000000  -1739.260000  -1787.500000
# 25%        7.843000       7.692000     67.757500      0.977500      3.138500
# 50%       37.500000      15.385000    104.538000      3.390000     10.241000
# 75%       57.200500      29.730000    159.014000      7.397000     20.899000
# max      100.000000     100.000000   1868.724000    175.477000   1112.500000
#
#        주력제품 국내 시장점유율(퍼센트)  학력별 인력구성비(대졸)  벤처캐피털(투자조합포함) 투자 경험여부
# count        11467.000000   11467.000000                11467.0
# mean            10.478083      47.750284                    0.0
# std             15.556511      24.375302                    0.0
# ...

# %%
b = a[a['벤처캐피털(투자조합포함) 투자 경험여부']==1]

# %%
c = a[a['벤처캐피털(투자조합포함) 투자 경험여부']==0]

# %%
b.sort_values('순이익률',ascending=False)[:30]
# Out:
#        부서별_인력구성(생산)  부서별_인력구성(RnD)    총자산회전율     순이익률       ROE  \
# 11453         0.000         66.667  1868.724  175.477  1112.500
# 8894          2.727          0.000     6.737  175.477    41.998
# 5227          0.000         60.000  1868.724  175.477  1112.500
# 9405         40.000         40.000    52.866   49.799    68.508
# 11345        39.189         16.216    45.928   48.352    61.341
# 10367        11.111         77.778    82.242   47.148    45.062
# 4535         31.579         21.053     4.739   46.364     3.453
# 10246         0.000          0.000    21.085   41.747     9.077
# 11584         0.000          0.000    28.211   41.576    13.614
# 1078         14.493         50.725    23.853   41.239    10.280
# 11362         0.000        100.000   132.884   40.228    85.676
# 2531         56.757         16.216    95.233   38.353    80.018
# 2361         80.000          0.000    50.826   37.906    19.811
# 1402         35.484         38.710    57.172   34.240    24.538
# ...

# %%
b.sort_values('순이익률',ascending=True)[:30]
# Out:
#        부서별_인력구성(생산)  부서별_인력구성(RnD)  총자산회전율      순이익률       ROE  \
# 0             0.000         40.000   0.056 -1739.260   360.366
# 11479         0.000         50.000   0.994 -1739.260   -35.579
# 11455         9.091          6.061   0.466 -1739.260   -41.171
# 11448         0.000         66.667   0.000 -1739.260   -20.222
# 9933          0.000         45.714   0.232 -1739.260   -31.256
# 10127         0.000          6.667   2.725 -1739.260  -251.607
# 10169        20.000         46.667   0.777 -1739.260  -145.455
# 11394         0.000         91.892   0.082 -1739.260 -1653.241
# 8843          6.977          9.302   1.124 -1739.260  -240.909
# 2835         31.579         47.368   1.118 -1739.260   -46.408
# 11489         0.000         50.000   2.999 -1739.260  -122.528
# 1624          0.000         87.500   0.147 -1739.260    -9.433
# 4772          0.000         57.143   0.000 -1739.260   -18.683
# 5242         17.647          5.882   1.668 -1739.260   -64.709
# ...

# %%
c.sort_values('순이익률',ascending=False)[:30]
# Out:
#        부서별_인력구성(생산)  부서별_인력구성(RnD)    총자산회전율     순이익률       ROE
# 7205         77.778          0.000     0.575  175.477     4.599  \
# 11318        12.500         37.500    21.466  175.477   525.000
# 9962          0.000         45.455     3.403  175.477    19.259
# 7228          0.000         66.667  1868.724  175.477  1112.500
# 11171         0.000         16.667     1.539  175.477    60.089
# 11740         0.000        100.000  1868.724  175.477  1112.500
# 3273         33.333          0.000  1868.724  175.477  1112.500
# 653          61.538          0.000  1868.724  175.477  1112.500
# 4823         61.667         10.000    22.826  175.477    46.257
# 6562         71.429         14.286  1868.724  175.477  1112.500
# 7058         20.000         50.000  1868.724  175.477  1112.500
# 3419         11.111         11.111  1868.724  175.477  1112.500
# 1240         20.000         40.000  1868.724  175.477  1112.500
# 4024          0.000         33.333  1868.724  175.477  1112.500
# ...
