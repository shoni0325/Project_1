# %%
import pandas as pd

# %%
df2 = pd.read_csv('/Users/taewon/Documents/금융 빅데이터/project_1/trash/(완)data).csv')

# %%
df2.drop(columns=['회사주소_시(도)','한국표준산업분류(KSIC)코드_10차','상장여부','인수합병(MnA) 경험여부','가중치','벤처확인 유형'], inplace=True)

# %% [markdown]
# feature selection 전 data
# - Min&Max Scailing X
# - One Hot Encoding X

# %% [markdown]
# 1. 범주형 변수

# %%
# 제품및서비스구조
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
b["제품및서비스구조"].value_counts()
# Out:
# 제품및서비스구조
# 3.0    391
# 2.0    379
# 1.0    147
# Name: count, dtype: int64

# %%
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
b["제품및서비스구조"].value_counts()
# Out:
# 제품및서비스구조
# 2.0    5192
# 3.0    4296
# 1.0    1980
# Name: count, dtype: int64

# %%
# 제조 및 비제조
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
b["제조 및 비제조"].value_counts()
# Out:
# 제조 및 비제조
# 1    334
# 4    272
# 2    269
# 3     42
# Name: count, dtype: int64

# %%
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
b["제조 및 비제조"].value_counts()
# Out:
# 제조 및 비제조
# 2    4070
# 1    3943
# 4    2978
# 3     477
# Name: count, dtype: int64

# %%
# 창업 당시 창업자 연령
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
b["창업 당시 창업자 연령"].value_counts()
# Out:
# 창업 당시 창업자 연령
# 2    375
# 3    355
# 4    131
# 1     32
# 5     24
# Name: count, dtype: int64

# %%
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
b["창업 당시 창업자 연령"].value_counts()
# Out:
# 창업 당시 창업자 연령
# 3    4978
# 2    4210
# 4    1559
# 5     373
# 1     348
# Name: count, dtype: int64

# %%
# 창업방식
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
b["창업방식"].value_counts()
# Out:
# 창업방식
# 3    797
# 2     62
# 1     58
# Name: count, dtype: int64

# %%
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
b["창업방식"].value_counts()
# Out:
# 창업방식
# 3    10782
# 2      350
# 1      336
# Name: count, dtype: int64

# %%
# 해외수출 및 진출과정 애로사항
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==1]
b["해외수출 및 진출과정 애로사항"].value_counts()
# Out:
# 해외수출 및 진출과정 애로사항
# 3.0    201
# 2.0    174
# 4.0    174
# 7.0    125
# 5.0     98
# 1.0     63
# 8.0     45
# 6.0     37
# Name: count, dtype: int64

# %%
b = df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==0]
b["해외수출 및 진출과정 애로사항"].value_counts()
# Out:
# 해외수출 및 진출과정 애로사항
# 3.0    2995
# 2.0    2332
# 4.0    1894
# 1.0    1442
# 5.0    1108
# 7.0     847
# 8.0     538
# 6.0     312
# Name: count, dtype: int64

# %% [markdown]
# 2. 비율 & 수치형 변수

# %%
df2 = df2[['주력제품 국내 시장점유율(퍼센트)',
 '주력제품 해외 시장점유율(퍼센트)',
 '정규직비율',
 '학력별 인력구성비(고졸이하)',
 '학력별 인력구성비(전문대졸)',
 '학력별 인력구성비(대졸)',
 '학력별 인력구성비(석사)',
 '학력별 인력구성비(박사)',
 '부서별_인력구성(관리)',
 '부서별_인력구성(생산)',
 '부서별_인력구성(영업)',
 '부서별_인력구성(RnD)',
 '부서별_인력구성(기타)',
 '매출구조비율(대기업)',
 '매출구조비율(12차벤더)',
 '매출구조비율(중소기업)',
 '매출구조비율(B2C)',
 '매출구조비율(B2G)',
 '매출구조비율(글로벌)',
 '투자액비(국내설비)',
 '투자액비(RnD)',
 '투자액비(해외)',
 '투자액비(기타)',
 '부채비율',
 '자기자본비율',
 '순이익률',
 '총자산회전율',
 '자기자본회전율',
 'ROE',
 '영업이익률',
 '이자보상배율',
 '종사자생산성',
 '창업 당시 창업자 실무경험 년수(년)',
 '벤처확인제도 혜택(평균)',
 '벤처인프라 수준(평균)',
 '등록보유(합계)',
 '출원중(합계)',
 '경영상 애로사항(개수)',
 '벤처캐피털(투자조합포함) 투자 경험여부']]

# %%
df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==1].describe()
# Out:
#        주력제품 국내 시장점유율(퍼센트)  주력제품 해외 시장점유율(퍼센트)       정규직비율  학력별 인력구성비(고졸이하)
# count          917.000000          917.000000  915.000000       917.000000  \
# mean            15.450218            2.863075    0.980191        17.091252
# std             19.197304            8.046664    0.072356        19.335027
# min              0.000000            0.000000    0.135000         0.000000
# 25%              2.000000            0.000000    1.000000         0.000000
# 50%              8.000000            0.010000    1.000000        10.000000
# 75%             20.000000            1.000000    1.000000        29.000000
# max            100.000000           80.000000    1.000000        92.000000
#
#        학력별 인력구성비(전문대졸)  학력별 인력구성비(대졸)  학력별 인력구성비(석사)  학력별 인력구성비(박사)
# count       917.000000     917.000000     917.000000     917.000000  \
# mean         15.409438      54.359083       9.560358       3.579869
# std          12.324227      23.405696      11.648341       7.525801
# ...

# %%
df2[df2["벤처캐피털(투자조합포함) 투자 경험여부"]==0].describe()
# Out:
#        주력제품 국내 시장점유율(퍼센트)  주력제품 해외 시장점유율(퍼센트)         정규직비율  학력별 인력구성비(고졸이하)
# count        11468.000000        11468.000000  11446.000000     11468.000000  \
# mean            10.478478            1.090296      0.987724        25.182434
# std             15.555890            5.550095      0.063103        24.014220
# min              0.000000            0.000000      0.016000         0.000000
# 25%              1.000000            0.000000      1.000000         0.000000
# 50%              5.000000            0.000000      1.000000        20.000000
# 75%             10.000000            0.010000      1.000000        45.000000
# max            100.000000          100.000000      1.000000       100.000000
#
#        학력별 인력구성비(전문대졸)  학력별 인력구성비(대졸)  학력별 인력구성비(석사)  학력별 인력구성비(박사)
# count     11468.000000   11468.000000   11468.000000   11468.000000  \
# mean         18.936181      47.748649       6.543709       1.589026
# std          14.207847      24.374866      10.332650       5.244736
# ...

# %%
a = df2[df2['벤처캐피털(투자조합포함) 투자 경험여부']==1]

# %%
b = df2[df2['벤처캐피털(투자조합포함) 투자 경험여부']==0]

# %%
a.sort_values('주력제품 국내 시장점유율(퍼센트)',ascending=False)[:30]
# Out:
#        주력제품 국내 시장점유율(퍼센트)  주력제품 해외 시장점유율(퍼센트)  정규직비율  학력별 인력구성비(고졸이하)
# 5233                100.0               50.00  1.000         0.000000  \
# 6825                100.0               30.00  1.000        69.400000
# 1267                 90.0               40.00  1.000        33.000000
# 2155                 90.0               30.00  1.000        50.000000
# 3104                 90.0                5.00  1.000        71.000000
# 3184                 85.0               10.00  1.000        29.710145
# 9755                 80.0                0.00  0.950         0.000000
# 7240                 80.0                3.00  1.000        30.769231
# 11540                80.0               20.00  1.000         0.000000
# 1507                 80.0               30.00  0.510        52.000000
# 4075                 75.0               30.00  1.000         6.514658
# 1645                 70.0               10.00  1.000        40.000000
# ...

# %%
b.sort_values('주력제품 국내 시장점유율(퍼센트)',ascending=False)[:30]
# Out:
#        주력제품 국내 시장점유율(퍼센트)  주력제품 해외 시장점유율(퍼센트)  정규직비율  학력별 인력구성비(고졸이하)
# 2480               100.00               30.00  0.950             50.0  \
# 3751               100.00                0.00  1.000             10.0
# 977                100.00                0.00  1.000              0.0
# 3263               100.00                0.00  1.000             14.0
# 6102               100.00                1.00  0.971             32.0
# 7092               100.00                0.00  1.000             90.0
# 2177               100.00                0.00  1.000             59.0
# 10152              100.00                0.00  1.000              6.6
# 7531               100.00                0.00  1.000             83.0
# 7731               100.00                0.00  1.000             45.0
# 2516               100.00                1.00  1.000             24.0
# 1278               100.00               70.00  1.000              7.0
# ...
